# %%
import yaml

# List of class names
classes = [
    "Dascyllus_reticulatus",
    "Plectroglyphidodon_dickii",
    "Chromis_chrysura",
    "Amphiprion_clarkii",
    "Chaetodon_lunulatus",
    "Chaetodon_trifascialis",
    "Myripristis_kuntee",
    "Acanthurus_nigrofuscus",
    "Hemigymnus_fasciatus",
    "Neoniphon_sammara",
    "Abudefduf_vaigiensis",
    "Canthigaster_valentini",
    "Pomacentrus_moluccensis",
    "Zebrasoma_scopas",
    "Hemigymnus_melapterus",
    "Lutjanus_fulvus",
    "Scolopsis_bilineata",
    "Scaridae",
    "Pempheris_vanicolensis",
    "Zanclus_cornutus",
    "Neoglyphidodon_nigroris",
    "Balistapus_undulatus",
    "Siganus_fuscescens"
]

dataset_dict = {
    "train": "/kaggle/input/fish4classification/dataset/dataset/images/train",
    "val": "/kaggle/input/fish4classification/dataset/dataset/images/val",
    "nc": len(classes),
    "names": classes
}

with open("dataset.yaml", "w") as f:
    yaml.dump(dataset_dict, f, sort_keys=False)

print("dataset.yaml generated!")
# Out:
# dataset.yaml generated!

# %%
# Install ultralytics (YOLOv8) on Kaggle or Colab
# !pip install --upgrade ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 23.1 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 53.0 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 49.6 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 37.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.9 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.3 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 6.0 MB/s eta 0:00:000:00:0100:01
# ...

# %%
from ultralytics import YOLO

# Path to the YAML file and model, change as needed
yaml_path = '/kaggle/working/dataset.yaml'
model_name = 'yolov8s-seg.pt'  # or 'yolov8m-seg.pt', etc.

# Create and train the YOLOv8 segmentation model
model = YOLO(model_name)

# Train
model.train(
    data=yaml_path,
    epochs=15,
    imgsz=640,
    batch=8,
    project='/kaggle/working/yolov8-seg-results',
    name='fish_segmentation',
    save=True,
    workers=2
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 22.8M/22.8M [00:00<00:00, 199MB/s]
# Ultralytics 8.3.168 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...
